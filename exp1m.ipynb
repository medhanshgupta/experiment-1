# %% [markdown]
# Experiment 1: Introduction to python
#
# medhansh gupta 25070123074

# %%
x,y,z="apple","orange","cherry"
print(x,y,z,sep="\n")
# Out:
# apple
# orange
# cherry

# %%
x,y,z,w=2,2.5,"me",True
print(type(x),type(y),type(z),type(w),sep="\n")
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
a,b=5,2
print("add=",a+b,"\nsub=",a-b,"\nmul=",a*b,"\ndiv=",a/b,"\nexp=",a**b)
# Out:
# add= 7
# sub= 3
# mul= 10
# div= 2.5
# exp= 25

# %%
a=int(input("enter value of a: "))
b=int(input("enter value of b: "))
print("add=",a+b,"\nsub=",a-b,"\nmul=",a*b,"\ndiv=",a/b,"\nexp=",a**b)
# Out:
# enter value of a: 5
# enter value of b: 2
# add= 7
# sub= 3
# mul= 10
# div= 2.5
# exp= 25

# %%
import math
r=float(input("enter radius: "))
print("area of circle = ",math.pi*r*r)
# Out:
# enter radius: 5
# area of circle =  78.53981633974483

# %%
import math
print("value of log 10 base 10 : ",math.log10(10))
# Out:
# value of log 10 base 10 :  1.0

# %%
import math
print("value of sin 60 : ",math.sin(math.pi/3))
# Out:
# value of sin 60 :  0.8660254037844386

# %%
a,b=10,5
if a>b:
  print("b is less than a")
else:
  print("b is greater than a")
# Out:
# b is less than a

# %%
a=int(input("enter value of a: "))
b=int(input("enter value of b: "))
if a>b:
  print("b is less than a")
else:
  print("b is greater than a")
# Out:
# enter value of a: 5
# enter value of b: 7
# b is greater than a
